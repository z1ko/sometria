# %%
from sometria.dataset import preprocess
from sometria.human import _load_human_definition

# %%
df = preprocess(
    input_root="/home/z1ko/datasets/sometria/hpc_v2_with_babel_actions",
    pattern="**/*.csv",
    human=_load_human_definition("/home/z1ko/develop/sometria/config/human.yaml"),
    save_path="/home/z1ko/develop/sometria/data/processed"
)
df
# Out:
# Processed 100/17453 samples
# Processed 200/17453 samples
# Processed 300/17453 samples
# Processed 400/17453 samples
# Processed 500/17453 samples
# Processed 600/17453 samples
# Processed 700/17453 samples
# Processed 800/17453 samples
# Processed 900/17453 samples
# Processed 1000/17453 samples
# Processed 1100/17453 samples
# Processed 1200/17453 samples
# Processed 1300/17453 samples
# Processed 1400/17453 samples
# Processed 1500/17453 samples
# Processed 1600/17453 samples
# Processed 1700/17453 samples
# Processed 1800/17453 samples
# Processed 1900/17453 samples
# Processed 2000/17453 samples
# Processed 2100/17453 samples
# Processed 2200/17453 samples
# Processed 2300/17453 samples
# Processed 2400/17453 samples
# Processed 2500/17453 samples
# Processed 2600/17453 samples
# Processed 2700/17453 samples
# Processed 2800/17453 samples
# Processed 2900/17453 samples
# Processed 3000/17453 samples
# Processed 3100/17453 samples
# Processed 3200/17453 samples
# ...

# %%
df['original_hz'].max()
# Out:
# 59.988002399520234
