# %%
from sometria.human import _load_human_definition, _columns_kinematics, _load_sample, _normalize_sample_torque

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
human_model = _load_human_definition("../config/human.yaml")
print(f'dofs: {human_model["dofs"]}')
# Out:
# dofs: ['pelvis_tilt', 'pelvis_list', 'pelvis_rotation', 'pelvis_tx', 'pelvis_ty', 'pelvis_tz', 'hip_flexion_r', 'hip_adduction_r', 'hip_rotation_r', 'knee_angle_r', 'ankle_angle_r', 'subtalar_angle_r', 'mtp_angle_r', 'hip_flexion_l', 'hip_adduction_l', 'hip_rotation_l', 'knee_angle_l', 'ankle_angle_l', 'subtalar_angle_l', 'mtp_angle_l', 'lumbar_bending', 'lumbar_extension', 'lumbar_twist', 'thorax_bending', 'thorax_extension', 'thorax_twist', 'head_bending', 'head_extension', 'head_twist', 'scapula_abduction_r', 'scapula_elevation_r', 'scapula_upward_rot_r', 'scapula_abduction_l', 'scapula_elevation_l', 'scapula_upward_rot_l', 'shoulder_r_x', 'shoulder_r_y', 'shoulder_r_z', 'shoulder_l_x', 'shoulder_l_y', 'shoulder_l_z', 'elbow_flexion_r', 'elbow_flexion_l', 'pro_sup_r', 'pro_sup_l', 'wrist_flexion_r', 'wrist_deviation_r', 'wrist_flexion_l', 'wrist_deviation_l']

# %%
print("kinematics colunms:")
_columns_kinematics(human_model)
# Out:
# kinematics colunms:
# ['pelvis_tilt',
#  'pelvis_tilt_vel',
#  'pelvis_tilt_acc',
#  'pelvis_tilt_tau',
#  'pelvis_list',
#  'pelvis_list_vel',
#  'pelvis_list_acc',
#  'pelvis_list_tau',
#  'pelvis_rotation',
#  'pelvis_rotation_vel',
#  'pelvis_rotation_acc',
#  'pelvis_rotation_tau',
#  'pelvis_tx',
#  'pelvis_tx_vel',
#  'pelvis_tx_acc',
#  'pelvis_tx_tau',
#  'pelvis_ty',
#  'pelvis_ty_vel',
#  'pelvis_ty_acc',
#  'pelvis_ty_tau',
#  'pelvis_tz',
#  'pelvis_tz_vel',
#  'pelvis_tz_acc',
#  'pelvis_tz_tau',
#  'hip_flexion_r',
#  'hip_flexion_r_vel',
#  'hip_flexion_r_acc',
#  'hip_flexion_r_tau',
#  'hip_adduction_r',
#  'hip_adduction_r_vel',
#  'hip_adduction_r_acc',
#  'hip_adduction_r_tau',
#  'hip_rotation_r',
#  'hip_rotation_r_vel',
#  'hip_rotation_r_acc',
#  'hip_rotation_r_tau',
#  'knee_angle_r',
#  'knee_angle_r_vel',
#  'knee_angle_r_acc',
#  'knee_angle_r_tau',
#  'ankle_angle_r',
#  'ankle_angle_r_vel',
#  'ankle_angle_r_acc',
#  'ankle_angle_r_tau',
#  'subtalar_angle_r',
#  'subtalar_angle_r_vel',
#  'subtalar_angle_r_acc',
#  'subtalar_angle_r_tau',
#  'mtp_angle_r',
#  'mtp_angle_r_vel',
#  'mtp_angle_r_acc',
#  'mtp_angle_r_tau',
#  'hip_flexion_l',
#  'hip_flexion_l_vel',
#  'hip_flexion_l_acc',
#  'hip_flexion_l_tau',
#  'hip_adduction_l',
#  'hip_adduction_l_vel',
#  'hip_adduction_l_acc',
#  'hip_adduction_l_tau',
#  'hip_rotation_l',
#  'hip_rotation_l_vel',
#  'hip_rotation_l_acc',
#  'hip_rotation_l_tau',
#  'knee_angle_l',
#  'knee_angle_l_vel',
#  'knee_angle_l_acc',
#  'knee_angle_l_tau',
#  'ankle_angle_l',
#  'ankle_angle_l_vel',
#  'ankle_angle_l_acc',
#  'ankle_angle_l_tau',
#  'subtalar_angle_l',
#  'subtalar_angle_l_vel',
#  'subtalar_angle_l_acc',
#  'subtalar_angle_l_tau',
#  'mtp_angle_l',
#  'mtp_angle_l_vel',
#  'mtp_angle_l_acc',
#  'mtp_angle_l_tau',
#  'lumbar_bending',
#  'lumbar_bending_vel',
#  'lumbar_bending_acc',
#  'lumbar_bending_tau',
#  'lumbar_extension',
#  'lumbar_extension_vel',
#  'lumbar_extension_acc',
#  'lumbar_extension_tau',
#  'lumbar_twist',
#  'lumbar_twist_vel',
#  'lumbar_twist_acc',
#  'lumbar_twist_tau',
#  'thorax_bending',
#  'thorax_bending_vel',
#  'thorax_bending_acc',
#  'thorax_bending_tau',
#  'thorax_extension',
#  'thorax_extension_vel',
#  'thorax_extension_acc',
#  'thorax_extension_tau',
#  'thorax_twist',
#  'thorax_twist_vel',
#  'thorax_twist_acc',
#  'thorax_twist_tau',
#  'head_bending',
#  'head_bending_vel',
#  'head_bending_acc',
#  'head_bending_tau',
#  'head_extension',
#  'head_extension_vel',
#  'head_extension_acc',
#  'head_extension_tau',
#  'head_twist',
#  'head_twist_vel',
#  'head_twist_acc',
#  'head_twist_tau',
#  'scapula_abduction_r',
#  'scapula_abduction_r_vel',
#  'scapula_abduction_r_acc',
#  'scapula_abduction_r_tau',
#  'scapula_elevation_r',
#  'scapula_elevation_r_vel',
#  'scapula_elevation_r_acc',
#  'scapula_elevation_r_tau',
#  'scapula_upward_rot_r',
#  'scapula_upward_rot_r_vel',
#  'scapula_upward_rot_r_acc',
#  'scapula_upward_rot_r_tau',
#  'scapula_abduction_l',
#  'scapula_abduction_l_vel',
#  'scapula_abduction_l_acc',
#  'scapula_abduction_l_tau',
#  'scapula_elevation_l',
#  'scapula_elevation_l_vel',
#  'scapula_elevation_l_acc',
#  'scapula_elevation_l_tau',
#  'scapula_upward_rot_l',
#  'scapula_upward_rot_l_vel',
#  'scapula_upward_rot_l_acc',
#  'scapula_upward_rot_l_tau',
#  'shoulder_r_x',
#  'shoulder_r_x_vel',
#  'shoulder_r_x_acc',
#  'shoulder_r_x_tau',
#  'shoulder_r_y',
#  'shoulder_r_y_vel',
#  'shoulder_r_y_acc',
#  'shoulder_r_y_tau',
#  'shoulder_r_z',
#  'shoulder_r_z_vel',
#  'shoulder_r_z_acc',
#  'shoulder_r_z_tau',
#  'shoulder_l_x',
#  'shoulder_l_x_vel',
#  'shoulder_l_x_acc',
#  'shoulder_l_x_tau',
#  'shoulder_l_y',
#  'shoulder_l_y_vel',
#  'shoulder_l_y_acc',
#  'shoulder_l_y_tau',
#  'shoulder_l_z',
#  'shoulder_l_z_vel',
#  'shoulder_l_z_acc',
#  'shoulder_l_z_tau',
#  'elbow_flexion_r',
#  'elbow_flexion_r_vel',
#  'elbow_flexion_r_acc',
#  'elbow_flexion_r_tau',
#  'elbow_flexion_l',
#  'elbow_flexion_l_vel',
#  'elbow_flexion_l_acc',
#  'elbow_flexion_l_tau',
#  'pro_sup_r',
#  'pro_sup_r_vel',
#  'pro_sup_r_acc',
#  'pro_sup_r_tau',
#  'pro_sup_l',
#  'pro_sup_l_vel',
#  'pro_sup_l_acc',
#  'pro_sup_l_tau',
#  'wrist_flexion_r',
#  'wrist_flexion_r_vel',
#  'wrist_flexion_r_acc',
#  'wrist_flexion_r_tau',
#  'wrist_deviation_r',
#  'wrist_deviation_r_vel',
#  'wrist_deviation_r_acc',
#  'wrist_deviation_r_tau',
#  'wrist_flexion_l',
#  'wrist_flexion_l_vel',
#  'wrist_flexion_l_acc',
#  'wrist_flexion_l_tau',
#  'wrist_deviation_l',
#  'wrist_deviation_l_vel',
#  'wrist_deviation_l_acc',
#  'wrist_deviation_l_tau']

# %%
sample = _load_sample("~/datasets/sometria/hpc_v2_with_babel_actions/ACCAD/Female1General_c3d/A5_-_pick_up_box_stageii.csv", human_model)
#normalized_sample = _normalize_sample_torque(sample)
#normalized_sample

# %%
channel_index = human_model["channels"].index("tau")
dof_index = human_model["dofs"].index("lumbar_bending")

motion = sample["motion"][:, dof_index, channel_index]
plt.plot(motion)
plt.show()
